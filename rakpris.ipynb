# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#  Data fetched from http://www.räkpris.se/data
df = pd.read_csv("rakpris.csv", encoding='utf-8', header=0)
pd.created_at = pd.to_datetime(df.date, 
                               format='%Y%m%d')
df.index = pd.created_at
df.head()
# Out:
#                 date  kilo  boxes  auctionprice  customerprice
# date
# 2012-09-05  20120905  2778    190        175.30            317
# 2012-09-07  20120907  6058    408        132.51            239
# 2012-09-11  20120911  1513    106        167.01            302
# 2012-09-12  20120912  2310    155        153.65            278
# 2012-09-13  20120913  7849    531        170.95            309

# %%
df.index
# Out:
# DatetimeIndex(['2012-09-05', '2012-09-07', '2012-09-11', '2012-09-12',
#                '2012-09-13', '2012-09-14', '2012-09-18', '2012-09-19',
#                '2012-09-20', '2012-09-21',
#                ...
#                '2017-12-11', '2017-12-12', '2017-12-13', '2017-12-15',
#                '2017-12-16', '2017-12-18', '2017-12-19', '2017-12-20',
#                '2017-12-21', '2017-12-22'],
#               dtype='datetime64[ns]', name='date', length=1171, freq=None)

# %%
def price(df):
    fig = plt.figure(figsize=(15,7))
    ax = fig.add_subplot(111)
    plt.plot(df.customerprice)
    plt.plot(df.auctionprice)
    plt.legend()
    plt.show()
price(df)

# %%
def boxes(df):
    fig = plt.figure(figsize=(15,7))
    ax = fig.add_subplot(111)
    plt.plot(df.boxes)
    plt.legend()
    plt.show()
boxes(df)

# %%
def kilo(df):
    fig = plt.figure(figsize=(15,7))
    ax = fig.add_subplot(111)
    plt.plot(df.kilo)
    plt.legend()
    plt.show()
kilo(df)
